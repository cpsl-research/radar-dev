# %% [markdown]
# # TGS Salt Using mmSegmentation

# %%
# look at the dataset
import mmcv
import mmengine
import matplotlib.pyplot as plt
import os

dataset_path = "/data/TGS_Salt_Identification/train/"

#show the image
img = mmcv.imread("/data/TGS_Salt_Identification/train/images/003c477d7c.png")
plt.figure(figsize=(8,6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

# %%
#show the mask
#show the image
mask = mmcv.imread("/data/TGS_Salt_Identification/train/masks/003c477d7c.png")
plt.figure(figsize=(8,6))
plt.imshow(mmcv.bgr2rgb(mask))
plt.show()
